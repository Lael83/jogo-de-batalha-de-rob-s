# %%
robot_art = r"""
      0: {head_name}
      Is available: {head_status}
      Attack: {head_attack}
      Defense: {head_defense}
      Energy consumption: {head_energy_consump}
              ^
              |                  |1: {weapon_name}
              |                  |Is available: {weapon_status}
     ____     |    ____          |Attack: {weapon_attack}
    |oooo|  ____  |oooo| ------> |Defense: {weapon_defense}
    |oooo| '    ' |oooo|         |Energy consumption: {weapon_energy_consump}
    |oooo|/\_||_/\|oooo|
    `----' / __ \  `----'           |2: {left_arm_name}
   '/  |#|/\/__\/\|#|  \'           |Is available: {left_arm_status}
   /  \|#|| |/\| ||#|/  \           |Attack: {left_arm_attack}
  / \_/|_|| |/\| ||_|\_/ \          |Defense: {left_arm_defense}
 |_\/    O\=----=/O    \/_|         |Energy consumption: {left_arm_energy_consump}
 <_>      |=\__/=|      <_> ------> |
 <_>      |------|      <_>         |3: {right_arm_name}
 | |   ___|======|___   | |         |Is available: {right_arm_status}
// \\ / |O|======|O| \  //\\        |Attack: {right_arm_attack}
|  |  | |O+------+O| |  |  |        |Defense: {right_arm_defense}
|\/|  \_+/        \+_/  |\/|        |Energy consumption: {right_arm_energy_consump}
\__/  _|||        |||_  \__/
      | ||        || |          |4: {left_leg_name}
     [==|]        [|==]         |Is available: {left_leg_status}
     [===]        [===]         |Attack: {left_leg_attack}
      >_<          >_<          |Defense: {left_leg_defense}
     || ||        || ||         |Energy consumption: {left_leg_energy_consump}
     || ||        || || ------> |
     || ||        || ||         |5: {right_leg_name}
   __|\_/|__    __|\_/|__       |Is available: {right_leg_status}
  /___n_n___\  /___n_n___\      |Attack: {right_leg_attack}
                                |Defense: {right_leg_defense}
                                |Energy consumption: {right_leg_energy_consump}
"""

colors = {
    "Black": '\x1b[90m',
    "Blue": '\x1b[94m',
    "Cyan": '\x1b[96m',
    "Green": '\x1b[92m',
    "Magenta": '\x1b[95m',
    "Red": '\x1b[91m',
    "White": '\x1b[97m',
    "Yellow": '\x1b[93m',
}

class Part():
    def __init__(self, name: str, attack_level=0, defense_level=0, energy_consumption=0):
        self.name = name
        self.attack_level = attack_level
        self.defense_level = defense_level
        self.energy_consumption = energy_consumption
        self.destroyed = False  # Nova propriedade para controlar se a parte foi destruída

    def get_status_dict(self):
        formatted_name = self.name.replace(" ", "_").lower()
        return {
            "{}_name".format(formatted_name): self.name.upper(),
            "{}_status".format(formatted_name): not self.is_available(),
            "{}_attack".format(formatted_name): self.attack_level,
            "{}_defense".format(formatted_name): self.defense_level,
            "{}_energy_consump".format(formatted_name): self.energy_consumption,
        }

    def reduce_defense(self, attack_level):
        self.defense_level -= attack_level
        if self.defense_level <= 0:
            self.defense_level = 0
            self.destroyed = True  # Define como destruída quando a defesa chega a 0

    def is_available(self):
        return self.defense_level <= 0

class Robot():
    def __init__(self, name, color_code):
        self.name = name
        self.color_code = color_code
        self.energy = 100
        self.parts = [
            Part("Head", attack_level=5, defense_level=10, energy_consumption=5),
            Part("Weapon", attack_level=15, defense_level=15, energy_consumption=10),  # Defesa da weapon alterada
            Part("Left Arm", attack_level=3, defense_level=20, energy_consumption=10),
            Part("Right Arm", attack_level=6, defense_level=20, energy_consumption=10),
            Part("Left Leg", attack_level=4, defense_level=20, energy_consumption=15),
            Part("Right Leg", attack_level=8, defense_level=20, energy_consumption=15),
        ]
## if not permmiti inveter valores de boolean
    def is_there_available_part(self):
        for part in self.parts:
            if not part.destroyed:
                return True
        return False

    def is_on(self):
        return self.energy >= 0

    def print_status(self):
        print(self.color_code)
        str_robot = robot_art.format(**self.get_part_status())
        self.greet()
        self.print_energy()
        print(str_robot)
        print(colors["White"])
        self.check_part_status()  # Adiciona verificação do status das partes

    def greet(self):
         print("O nome do robô é", self.name)


    def print_energy(self):
       print("O robô tem", self.energy, "porcento de energia restante")

    def attack(self, enemy_robot, part_to_use, part_to_attack):
        enemy_part = enemy_robot.parts[part_to_attack]
        if enemy_part.destroyed:
            print("A parte alvo já está destruída.")
            return

        enemy_part.reduce_defense(self.parts[part_to_use].attack_level)
        self.energy -= self.parts[part_to_use].energy_consumption


## enumerate expressão retornará uma lista de tuplas, onde cada tupla contém o índice e a parte desse índice.
    def get_part_status(self):
       # Cria um dicionário vazio para armazenar os status das peças
        part_status = {}
        for index, part in enumerate(self.parts):
      # Obtém o dicionário de status da peça atual
            status_dict = part.get_status_dict()
       # Adiciona o dicionário de status da peça ao dicionário part_status
            part_status.update(status_dict)
        return part_status

    def check_part_status(self):
        for part in self.parts:
            if part.destroyed:
                print("A parte alvo '{}' foi completamente destruída.".format(part.name))
            elif part.defense_level == 3:
                  print("Aviso: a peça alvo '{}' está em condição crítica e pode funcionar mal.".format(part.name))

def build_robot():
    robot_name = input("Nome do robô: ")
    color_code = choose_color()
    robot = Robot(robot_name, color_code)
    robot.print_status()
    return robot

def choose_color():
    available_colors = colors
    print("Cores disponíveis:")
    for key, value in available_colors.items():
        print(value, key)
    print(colors["White"])
    chosen_color = input("Qual é a cor do robô: ")
    color_code = available_colors[chosen_color]
    return color_code

def play():
    playing = True
    print("Bem-vindo ao jogo!")
    print("Dados para o jogador 1:")
    robot_one = build_robot()
    print("Dados para o jogador 2:")
    robot_two = build_robot()

    current_robot = robot_one
    enemy_robot = robot_two
    round_num = 0

    while playing:
        if round_num % 2 == 0:
            current_robot = robot_one
            enemy_robot = robot_two
        else:
            current_robot = robot_two
            enemy_robot = robot_one

        current_robot.print_status()
        print("Qual parte usar para atacar o outro robô? ")
        part_to_use = input("Escolha a parte [0, 1, 2, 3, 4, 5]: ")
        part_to_use = int(part_to_use)

        enemy_robot.print_status()
        print("Qual parte do robô inimigo você quer atacar? ")
        part_to_attack = input("Escolha a parte [0, 1, 2, 3, 4, 5]: ")
        part_to_attack = int(part_to_attack)

        current_robot.attack(enemy_robot, part_to_use, part_to_attack)
        round_num += 1

        if not enemy_robot.is_on() or not enemy_robot.is_there_available_part():
            playing = False
            print("\nParabéns, {} venceu!".format(current_robot.name))

play()
# Out:
# Bem-vindo ao jogo!
# Dados para o jogador 1:
# Nome do robô: eu
# Cores disponíveis:
#  Black
#  Blue
#  Cyan
#  Green
#  Magenta
#  Red
#  White
#  Yellow
#
# Qual é a cor do robô: Blue
#
# O nome do robô é eu
# O robô tem 100 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: True
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 15
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Dados para o jogador 2:
# Nome do robô: tu
# Cores disponíveis:
#  Black
#  Blue
#  Cyan
#  Green
#  Magenta
#  Red
#  White
#  Yellow
#
# Qual é a cor do robô: Red
#
# O nome do robô é tu
# O robô tem 100 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: True
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 15
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
#
# O nome do robô é eu
# O robô tem 100 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: True
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 15
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Qual parte usar para atacar o outro robô?
# Escolha a parte [0, 1, 2, 3, 4, 5]: 1
#
# O nome do robô é tu
# O robô tem 100 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: True
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 15
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Qual parte do robô inimigo você quer atacar?
# Escolha a parte [0, 1, 2, 3, 4, 5]: 1
#
# O nome do robô é tu
# O robô tem 100 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: False
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 0
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# A parte alvo 'Weapon' foi completamente destruída.
# Qual parte usar para atacar o outro robô?
# Escolha a parte [0, 1, 2, 3, 4, 5]: 3
#
# O nome do robô é eu
# O robô tem 90 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 10
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: True
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 15
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Qual parte do robô inimigo você quer atacar?
# Escolha a parte [0, 1, 2, 3, 4, 5]: 0
#
# O nome do robô é eu
# O robô tem 90 porcento de energia restante
#
#       0: HEAD
#       Is available: True
#       Attack: 5
#       Defense: 4
#       Energy consumption: 5
#               ^
#               |                  |1: WEAPON
#               |                  |Is available: True
#      ____     |    ____          |Attack: 15
#     |oooo|  ____  |oooo| ------> |Defense: 15
#     |oooo| '    ' |oooo|         |Energy consumption: 10
#     |oooo|/\_||_/\|oooo|
#     `----' / __ \  `----'           |2: LEFT ARM
#    '/  |#|/\/__\/\|#|  \'           |Is available: True
#    /  \|#|| |/\| ||#|/  \           |Attack: 3
#   / \_/|_|| |/\| ||_|\_/ \          |Defense: 20
#  |_\/    O\=----=/O    \/_|         |Energy consumption: 10
#  <_>      |=\__/=|      <_> ------> |
#  <_>      |------|      <_>         |3: RIGHT ARM
#  | |   ___|======|___   | |         |Is available: True
# // \\ / |O|======|O| \  //\\        |Attack: 6
# |  |  | |O+------+O| |  |  |        |Defense: 20
# |\/|  \_+/        \+_/  |\/|        |Energy consumption: 10
# \__/  _|||        |||_  \__/
#       | ||        || |          |4: LEFT LEG
#      [==|]        [|==]         |Is available: True
#      [===]        [===]         |Attack: 4
#       >_<          >_<          |Defense: 20
#      || ||        || ||         |Energy consumption: 15
#      || ||        || || ------> |
#      || ||        || ||         |5: RIGHT LEG
#    __|\_/|__    __|\_/|__       |Is available: True
#   /___n_n___\  /___n_n___\      |Attack: 8
#                                 |Defense: 20
#                                 |Energy consumption: 15
#
#
# Qual parte usar para atacar o outro robô?
